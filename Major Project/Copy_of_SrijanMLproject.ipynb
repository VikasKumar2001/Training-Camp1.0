# %%
#importing Libraries
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df=pd.read_csv('Car_Price_Prediction Dataset.csv')

# %%
inputs=df.drop(['Location','Transmission'],axis='columns')
target=df.New_Price
target
# Out:
# 0             NaN
# 1             NaN
# 2       8.61 Lakh
# 3             NaN
# 4             NaN
#           ...
# 6014    7.88 Lakh
# 6015          NaN
# 6016          NaN
# 6017          NaN
# 6018          NaN
# Name: New_Price, Length: 6019, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
Numerics=LabelEncoder()

# %%
inputs['Year_n']=Numerics.fit_transform(inputs['Year'])
inputs['Price_n']=Numerics.fit_transform(inputs['Price'])
inputs
# Out:
#       Unnamed: 0                              Name  Year  Kilometers_Driven  \
# 0              0            Maruti Wagon R LXI CNG  2010              72000
# 1              1  Hyundai Creta 1.6 CRDi SX Option  2015              41000
# 2              2                      Honda Jazz V  2011              46000
# 3              3                 Maruti Ertiga VDI  2012              87000
# 4              4   Audi A4 New 2.0 TDI Multitronic  2013              40670
# ...          ...                               ...   ...                ...
# 6014        6014                  Maruti Swift VDI  2014              27365
# 6015        6015          Hyundai Xcent 1.1 CRDi S  2015             100000
# 6016        6016             Mahindra Xylo D4 BSIV  2012              55000
# 6017        6017                Maruti Wagon R VXI  2013              46000
# 6018        6018             Chevrolet Beat Diesel  2011              47000
#
# ...

# %%
inputs_n=inputs.drop(['Year','Price'],axis='columns')
inputs_n
# Out:
#       Unnamed: 0                              Name  Kilometers_Driven  \
# 0              0            Maruti Wagon R LXI CNG              72000
# 1              1  Hyundai Creta 1.6 CRDi SX Option              41000
# 2              2                      Honda Jazz V              46000
# 3              3                 Maruti Ertiga VDI              87000
# 4              4   Audi A4 New 2.0 TDI Multitronic              40670
# ...          ...                               ...                ...
# 6014        6014                  Maruti Swift VDI              27365
# 6015        6015          Hyundai Xcent 1.1 CRDi S             100000
# 6016        6016             Mahindra Xylo D4 BSIV              55000
# 6017        6017                Maruti Wagon R VXI              46000
# 6018        6018             Chevrolet Beat Diesel              47000
#
#      Fuel_Type Owner_Type     Mileage   Engine      Power  Seats  New_Price  \
# ...
