# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
videogame = pd.read_csv('videogames.csv')

# %%
videogame
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
videogame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# ...

# %%
# to find null values

# %%
videogame.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
#heat map

# %%
sns.heatmap(videogame.isnull(),yticklabels=False,cbar=False)

# %%
plt.figure(figsize = (18,25))
sns.heatmap(videogame.isnull(),yticklabels=False,cbar=False)

# %%
videogame.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
videogame.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count   User_Score  \
# count  16719.000000  16719.000000   8137.000000   8137.000000  7590.000000
# mean       0.047332      0.533543     68.967679     26.360821     7.125046
# std        0.186710      1.547935     13.938165     18.980495     1.500006
# min        0.000000      0.010000     13.000000      3.000000     0.000000
# ...

# %%
# now plotting graphs

# %%
# types of games =

# %%
videogame['Genre'].value_counts()
# Out:
# Action          3370
# Sports          2348
# Misc            1750
# Role-Playing    1500
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       874
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: Genre, dtype: int64

# %%
# type of game highly released

# %%
# countplot

# %%
plt.figure(figsize=(17,11))
sns.countplot(x="Genre", data=videogame, order = videogame['Genre'].value_counts().index)   
plt.xticks(rotation='vertical')   
plt.ylabel('Count')                 
plt.xlabel('Genre')                 
plt.show()

# %%
# pairplot

# %%
sns.pairplot(videogame)

# %%
# displot for year of release

# %%
sns.displot(data=videogame['Year_of_Release'])

# %%
# joint plot between year of release and global sales

# %%
sns.jointplot(x='Year_of_Release',y='Global_Sales',data=videogame)

# %%
# rugplot

# %%
sns.rugplot(videogame['Year_of_Release'])

# %%
# barplot to check which platform most games are there

# %%
plt.figure(figsize=(17,11))
sns.barplot(x='Platform',y='Global_Sales',data=videogame)

# %%
#box plot between yeaar of release and global sales

# %%
plt.figure(figsize=(15,11))
sns.boxplot(x='Year_of_Release',y='Global_Sales',data=videogame)

# %%
# most games released using countplot in decreasing order per year of realeased

# %%
plt.figure(figsize=(15, 10))
sns.countplot(x="Year_of_Release",data=videogame, order = videogame.groupby(by=['Year_of_Release'])['Name'].count().sort_values(ascending=False).index)
plt.xticks(rotation='vertical')    
plt.ylabel('Count')                     
plt.xlabel('Year')                      
plt.show()

# %%
plt.figure(figsize=(15, 10))
corr=videogame.corr()
sns.heatmap(corr,annot=True)
plt.show()

# %%
# data cleaning

# %%
# removing of useless data

# %%
videogame.drop(['Name','Developer'],axis=1,inplace=True)

# %%
videogame.drop(['Rating'],axis=1,inplace=True)

# %%
videogame.isnull().sum()
# Out:
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# dtype: int64

# %%
# dropping columns with too many null values

# %%
videogame.drop(['User_Count','User_Score','Critic_Count','Critic_Score'],axis=1,inplace=True)

# %%
# removing useless data
#videogame.drop(['NA_Sales','EU_Sales','JP_Sales','Other_Sales'],axis=1,inplace=True)

# %%
videogame
# Out:
#       Platform  Year_of_Release         Genre     Publisher  NA_Sales  \
# 0          Wii           2006.0        Sports      Nintendo     41.36
# 1          NES           1985.0      Platform      Nintendo     29.08
# 2          Wii           2008.0        Racing      Nintendo     15.68
# 3          Wii           2009.0        Sports      Nintendo     15.61
# 4           GB           1996.0  Role-Playing      Nintendo     11.27
# ...        ...              ...           ...           ...       ...
# 16714      PS3           2016.0        Action    Tecmo Koei      0.00
# 16715     X360           2006.0        Sports   Codemasters      0.00
# 16716      PSV           2016.0     Adventure  Idea Factory      0.00
# 16717      GBA           2003.0      Platform       Wanadoo      0.01
# 16718      PSV           2016.0    Simulation    Tecmo Koei      0.00
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0         28.96      3.77         8.45         82.53
# ...

# %%
videogame.isnull().sum()
# Out:
# Platform             0
# Year_of_Release    269
# Genre                2
# Publisher           54
# NA_Sales             0
# EU_Sales             0
# JP_Sales             0
# Other_Sales          0
# Global_Sales         0
# dtype: int64

# %%
# filling null values in year by its mean values

# %%
videogame['Year_of_Release'] = videogame['Year_of_Release'].fillna(videogame['Year_of_Release'].mean())

# %%
videogame.isnull().sum()
# Out:
# Platform            0
# Year_of_Release     0
# Genre               2
# Publisher          54
# NA_Sales            0
# EU_Sales            0
# JP_Sales            0
# Other_Sales         0
# Global_Sales        0
# dtype: int64

# %%
videogame['Publisher'] = videogame['Publisher'].dropna(axis=0)

# %%
videogame.isnull().sum()
# Out:
# Platform            0
# Year_of_Release     0
# Genre               2
# Publisher          54
# NA_Sales            0
# EU_Sales            0
# JP_Sales            0
# Other_Sales         0
# Global_Sales        0
# dtype: int64

# %%
videogame= videogame.dropna(axis=0)

# %%
videogame.isnull().sum()
# Out:
# Platform           0
# Year_of_Release    0
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# dtype: int64

# %%
videogame
# Out:
#       Platform  Year_of_Release         Genre     Publisher  NA_Sales  \
# 0          Wii           2006.0        Sports      Nintendo     41.36
# 1          NES           1985.0      Platform      Nintendo     29.08
# 2          Wii           2008.0        Racing      Nintendo     15.68
# 3          Wii           2009.0        Sports      Nintendo     15.61
# 4           GB           1996.0  Role-Playing      Nintendo     11.27
# ...        ...              ...           ...           ...       ...
# 16714      PS3           2016.0        Action    Tecmo Koei      0.00
# 16715     X360           2006.0        Sports   Codemasters      0.00
# 16716      PSV           2016.0     Adventure  Idea Factory      0.00
# 16717      GBA           2003.0      Platform       Wanadoo      0.01
# 16718      PSV           2016.0    Simulation    Tecmo Koei      0.00
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0         28.96      3.77         8.45         82.53
# ...

# %%
videogame['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
videogame['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
videogame['Publisher'].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment', 'Square Enix',
#        'Sony Computer Entertainment Europe', 'Virgin Interactive',
#        'LucasArts', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        'Codemasters', 'Majesco Entertainment', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        'NCSoft', '989 Studios', 'UEP Systems', 'Parker Bros.', 'Maxis',
# ...

# %%
videogame.drop(['Platform','Genre','Publisher'],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#videogame['Publisher'].value_counts()

# %%
# there are many values for publisher so merging small counts into one

# %%
# name them less_sold_ones

# %%
from sklearn.model_selection import train_test_split

# %%
X = videogame.drop('Global_Sales',axis = 1)
y = videogame['Global_Sales']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=52)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
colums = ['Platform','Genre','Publisher']

# %%
#pd.get_dummies(videogame['Platform'])

# %%
videogame

# %%
regr = LinearRegression()
regr.fit(X_train,y_train)
prediction=regr.predict(X_test)

# %%
prediction
# Out:
# array([1.51008582, 0.57024083, 0.18029336, ..., 0.1102744 , 0.65024027,
#        0.07027456])

# %%
test_data_accuracy=accuracy_score(np.round(prediction),np.round(y_test))

# %%
print("Accuracy:",test_data_accuracy)
# Out:
# Accuracy: 0.995999199839968
