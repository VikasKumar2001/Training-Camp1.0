# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
heart=pd.read_csv('/content/heartDisease.csv')
heart
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
heart.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4238.000000  4238.000000  4133.000000    4238.000000  4209.000000
# mean      0.429212    49.584946     1.978950       0.494101     9.003089
# std       0.495022     8.572160     1.019791       0.500024    11.920094
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4185.000000      4238.000000   4238.000000  4238.000000  4188.000000
# mean      0.029630         0.005899      0.310524     0.025720   236.721585
# std       0.169584         0.076587      0.462763     0.158316    44.590334
# ...

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
heart.count()
# Out:
# male               4238
# age                4238
# education          4133
# currentSmoker      4238
# cigsPerDay         4209
# BPMeds             4185
# prevalentStroke    4238
# prevalentHyp       4238
# diabetes           4238
# totChol            4188
# sysBP              4238
# diaBP              4238
# BMI                4219
# heartRate          4237
# glucose            3850
# TenYearCHD         4238
# dtype: int64

# %%
heart.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
sns.heatmap(heart.isnull(),yticklabels=False,cbar=False)

# %%
sns.countplot(x='currentSmoker',data=heart)

# %%
sns.countplot(x='male',data=heart)

# %%
sns.countplot(x='prevalentStroke',data=heart)

# %%
sns.countplot(x='prevalentHyp',data=heart)

# %%
sns.countplot(x='diabetes',data=heart)

# %%
from matplotlib import pyplot as pli
pli.figure(figsize=(30,10))
a=sns.countplot(x='age',data=heart)
a

# %%
sns.displot(x='age',hue='diabetes',data=heart)

# %%
pli.scatter(heart['totChol'],heart['age'],alpha=0.1)
pli.xlabel('totChol')
pli.ylabel('age')
pli.show()

# %%
corr=heart.corr()
pli.figure(figsize=(20,5))
sns.heatmap(corr,annot=True,cmap="gist_rainbow")
pli.show()
heart=heart.dropna()

# %%
x=heart.drop('TenYearCHD',axis=1)
y=heart['TenYearCHD']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=.33)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predic1=lr.predict(x_test)
predic1
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,predic1))
# Out:
# 0.8417564208782105

# %%
a=int(input("male: "))
b=int(input("age: "))
c=int(input("education: "))
d=int(input("Current Smoker: "))
e=int(input("Cigarattes per day"))
f=int(input("BM Meds"))
g=int(input("Prevalent Stroke"))
h=int(input("Prevalent Hyp: "))
i=int(input("Diabetes: "))
j=int(input("total cholesterol level: "))
k=float(input("systolic blood pressure: "))
l=float(input("diastolic blood pressure: "))
m=float(input("body mass index: "))
n=int(input("Heart Rate: "))
o=int(input("Glucose Level: "))
# Out:
# male: 1
# age: 28
# education: 3
# Current Smoker: 1
# Cigarattes per day6
# BM Meds0
# Prevalent Stroke0
# Prevalent Hyp: 0
# Diabetes: 1
# total cholesterol level: 200
# systolic blood pressure: 94
# diastolic blood pressure: 97
# body mass index: 25
# Heart Rate: 77
# Glucose Level: 89

# %%
data={'male':[a],'age':[b],'education':[c],'currentSmoker':[d],'cigsPerDay':[e],'BPMeds':[f],'prevalentStroke':[g],'prevalentHyp':[h],'diabetes':[i],'totchol':[j],'sysBP':[k],'diaBP':[l],'BMI':[m],'heartRate':[n],'glucose':[o]}

# %%
hd=pd.DataFrame(data)

# %%
hd
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   28          3              1           6       0                0
#
#    prevalentHyp  diabetes  totchol  sysBP  diaBP   BMI  heartRate  glucose
# 0             0         1      200   94.0   97.0  25.0         77       89

# %%
predic=lr.predict(hd)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - totchol
# Feature names seen at fit time, yet now missing:
# - totChol
#
#   warnings.warn(message, FutureWarning)

# %%
if predic == 1:
    print("This person is suffering from an heart disease")
else:
    print("This person is not suffering from an heart disease")
# Out:
# This person is not suffering from an heart disease
